# %%
#1
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager #always use the latest version of chrome driver to support the currect chrome version
from selenium.webdriver.support.ui import WebDriverWait #enables to wait until condition is fullfilled or just until a timeout exception is returned
from selenium.webdriver.support import expected_conditions as ec #enables to create the conditions
from selenium.webdriver.common.by import By #use the method to select
from selenium.webdriver.common.keys import Keys
import time
from bs4 import BeautifulSoup
from pymongo import MongoClient

# %%
#2
#Well done Facebook by sending alerts to prevent me from scraping your website, but thanks to chrome options, I can easily bypass it  
chrome_options = webdriver.ChromeOptions() 
prefs = {"profile.default_content_setting_values.notifications" : 2}
chrome_options.add_experimental_option("prefs",prefs)

# %%
#3
driver = webdriver.Chrome(ChromeDriverManager().install(), chrome_options=chrome_options)
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 100.0.4896
# Get LATEST chromedriver version for 100.0.4896 google-chrome
# Trying to download new driver from https://chromedriver.storage.googleapis.com/100.0.4896.60/chromedriver_win32.zip
# Driver has been saved in cache [C:\Users\Rania Fradi\.wdm\drivers\chromedriver\win32\100.0.4896.60]
# C:\Users\Rania Fradi\AppData\Local\Temp\ipykernel_17652\2349977395.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install(), chrome_options=chrome_options)
# C:\Users\Rania Fradi\AppData\Local\Temp\ipykernel_17652\2349977395.py:2: DeprecationWarning: use options instead of chrome_options
#   driver = webdriver.Chrome(ChromeDriverManager().install(), chrome_options=chrome_options)

# %%
#4
driver.get("http://www.facebook.com/")

# %%
#5
#target user info
username = WebDriverWait(driver, 10).until(ec.element_to_be_clickable((By.CSS_SELECTOR, "input[name='email']")))
password = WebDriverWait(driver, 10).until(ec.element_to_be_clickable((By.CSS_SELECTOR, "input[name='pass']")))

#enter username and password
username.clear()
username.send_keys("panqueque@cuenmex.com") #automatically generated by an email generator
password.clear()
password.send_keys("abc123;")

#click on the login button
flog_in = WebDriverWait(driver, 2).until(ec.element_to_be_clickable((By.CSS_SELECTOR, "button[type='submit']"))).click()
time.sleep(5)

# %%
#6
l=driver.find_element_by_css_selector("div[aria-label='Rechercher sur Facebook']").click()
# Out:
# C:\Users\Rania Fradi\AppData\Local\Temp\ipykernel_17652\582568288.py:2: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   l=driver.find_element_by_css_selector("div[aria-label='Rechercher sur Facebook']").click()

# %%
#7
input=driver.find_element_by_css_selector("input[aria-label='Rechercher sur Facebook']")

input.clear()
time.sleep(2)

keyword = "#décèsdejacqueschirac"
input.send_keys(keyword)
time.sleep(5)

input.send_keys(Keys.ENTER)
# Out:
# C:\Users\Rania Fradi\AppData\Local\Temp\ipykernel_17652\850141344.py:2: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   input=driver.find_element_by_css_selector("input[aria-label='Rechercher sur Facebook']")

# %%
#8
for j in range(5):
    
    ktxt= driver.find_elements_by_css_selector("div[class='oajrlxb2 g5ia77u1 qu0x051f esr5mh6w e9989ue4 r7d6kgcz rq0escxv nhd2j8a9 nc684nl6 p7hjln8o kvgmc6g5 cxmmr5t8 oygrvhab hcukyx3x jb3vyjys rz4wbd8a qt6c0cv9 a8nywdso i1ao9s8h esuyzwwr f1sip0of lzcic4wl gpro0wi8 oo9gr5id lrazzd5p']")
    for i in ktxt:
        i.click() #to activate 'voir plus' button

    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(5)
# Out:
# C:\Users\Rania Fradi\AppData\Local\Temp\ipykernel_17652\4024482962.py:4: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   ktxt= driver.find_elements_by_css_selector("div[class='oajrlxb2 g5ia77u1 qu0x051f esr5mh6w e9989ue4 r7d6kgcz rq0escxv nhd2j8a9 nc684nl6 p7hjln8o kvgmc6g5 cxmmr5t8 oygrvhab hcukyx3x jb3vyjys rz4wbd8a qt6c0cv9 a8nywdso i1ao9s8h esuyzwwr f1sip0of lzcic4wl gpro0wi8 oo9gr5id lrazzd5p']")

# %%
#9
soup = BeautifulSoup(driver.page_source,"html.parser")
all_posts = soup.find_all("div",{"class":"du4w35lb k4urcfbm l9j0dhe7 sjgh65i0"})

# %%
#10
#extract images
name=[]
for post in all_posts:
    name.append(post.find("img"))

# %%
#11
#extract sources from images
images=[]
for i in name: 
    images.append(i['src'])
images
# Out:
# ['https://scontent.ftun15-1.fna.fbcdn.net/v/t1.6435-9/70218735_2520182701394690_4579251791207596032_n.jpg?stp=dst-jpg_s1080x2048&_nc_cat=110&ccb=1-5&_nc_sid=730e14&_nc_ohc=qiwu30SPiqcAX-1TXXG&_nc_ht=scontent.ftun15-1.fna&oh=00_AT9hoz9xfsS3DVeI-gNmQI6IJiQ8w-pLG8vOH_DSB5CZNQ&oe=62898F30',
#  'https://external.ftun15-1.fna.fbcdn.net/safe_image.php?w=445&h=232&url=http%3A%2F%2Foutremers360.com%2Fwp-media%2Fuploads%2Fbfi_thumb%2FCapture-d%E2%80%99%C3%A9cran-2019-09-26-%C3%A0-15.41.58-oeh6yq1wncyqnlij9h47rex7cac3iczygxgsfbp6fg.png&cfs=1&sx=0&sy=13&sw=445&sh=232&ext=jpg&_nc_oe=6ff9e&_nc_sid=632586&_nc_o2e=1&ccb=3-6&_nc_hash=AQHZtNKwhe7zUZfm',
#  'https://scontent.ftun15-1.fna.fbcdn.net/v/t1.6435-9/71489988_2518058671607093_6082894067438452736_n.jpg?stp=dst-jpg_s1080x2048&_nc_cat=101&ccb=1-5&_nc_sid=730e14&_nc_ohc=LjKimQFFsU0AX9l0mVp&_nc_ht=scontent.ftun15-1.fna&oh=00_AT_6DyYJJsCEigHUWc4lJc5vsIEMgLBDe8uXmYduu-KKhQ&oe=6289D94C',
# ...

# %%
#13
descriptions
# Out:
# ['Le #DessinDePresse de Zaïtchick : To be or not to be... Not to be !Emmanuel Macron et Christophe Castaner : « - Comment devenir aussi populaire que Jacques Chirac ?...- Heu… Mourez ?- Merci Christophe… J’y réfléchirai… »Retrouvez les dessins de Zaïtchick sur le sitehttps://www.blagues-et-dessins.com/.../l-actu-de-zaitchick/#DessinDeZaitchick #ActuDeZaitchick #Humour #HumourNoir #RIPJacquesChirac #DécèsDeJacquesChirac #JacquesChirac #MortDeJacquesChirac #DisparitionDeJacquesChirac #EmmanuelMacron #ChristopheCastaner',
#  'Avec émotion le témoignage de Mémona Hintermann Affejee',
#  '#DécèsdeJacquesChirac #Outremer « Ce n’était pas l’homme politique mais l’homme Chirac», confie la Réunionnaise Mémona Hintermann, ancienne conseillère au CSA et ancienne reporter sur France 3',
# ...

# %%
#14
driver.execute_script("window.scrollTo(document.body.scrollHeight,0);") #scroll up


kcm= driver.find_elements_by_css_selector("div[class='oajrlxb2 gs1a9yip mtkw9kbi tlpljxtp qensuy8j ppp5ayq2 nhd2j8a9 mg4g778l pfnyh3mw p7hjln8o tgvbjcpo hpfvmrgz esuyzwwr f1sip0of n00je7tq arfg74bv qs9ysxi8 k77z8yql pq6dq46d btwxx1t3 abiwlrkh lzcic4wl dwo3fsh8 g5ia77u1 goun2846 ccm00jje s44p3ltw mk2mc5f4 rt8b4zig n8ej3o3l agehan2d sk4xxmp2 rq0escxv gmql0nx0 kvgmc6g5 cxmmr5t8 oygrvhab hcukyx3x jb3vyjys rz4wbd8a qt6c0cv9 a8nywdso l9j0dhe7 i1ao9s8h du4w35lb gpro0wi8'][aria-expanded='false']")
for j in kcm:
    j.click() #to activate comment button
    
kcm= driver.find_elements_by_css_selector("div[class='oajrlxb2 gs1a9yip mtkw9kbi tlpljxtp qensuy8j ppp5ayq2 nhd2j8a9 mg4g778l pfnyh3mw p7hjln8o tgvbjcpo hpfvmrgz esuyzwwr f1sip0of n00je7tq arfg74bv qs9ysxi8 k77z8yql pq6dq46d btwxx1t3 abiwlrkh lzcic4wl dwo3fsh8 g5ia77u1 goun2846 ccm00jje s44p3ltw mk2mc5f4 rt8b4zig n8ej3o3l agehan2d sk4xxmp2 rq0escxv gmql0nx0 kvgmc6g5 cxmmr5t8 oygrvhab hcukyx3x jb3vyjys rz4wbd8a qt6c0cv9 a8nywdso l9j0dhe7 i1ao9s8h du4w35lb gpro0wi8'][aria-expanded='false']")
for j in kcm:
    j.click() #just need to be open twice :3
# Out:
# C:\Users\Rania Fradi\AppData\Local\Temp\ipykernel_17652\344573512.py:5: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   kcm= driver.find_elements_by_css_selector("div[class='oajrlxb2 gs1a9yip mtkw9kbi tlpljxtp qensuy8j ppp5ayq2 nhd2j8a9 mg4g778l pfnyh3mw p7hjln8o tgvbjcpo hpfvmrgz esuyzwwr f1sip0of n00je7tq arfg74bv qs9ysxi8 k77z8yql pq6dq46d btwxx1t3 abiwlrkh lzcic4wl dwo3fsh8 g5ia77u1 goun2846 ccm00jje s44p3ltw mk2mc5f4 rt8b4zig n8ej3o3l agehan2d sk4xxmp2 rq0escxv gmql0nx0 kvgmc6g5 cxmmr5t8 oygrvhab hcukyx3x jb3vyjys rz4wbd8a qt6c0cv9 a8nywdso l9j0dhe7 i1ao9s8h du4w35lb gpro0wi8'][aria-expanded='false']")
# C:\Users\Rania Fradi\AppData\Local\Temp\ipykernel_17652\344573512.py:9: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
# ...

# %%
driver.execute_script("window.scrollTo(document.body.scrollHeight,0);") #scroll up
all_posts = soup.find_all("div",{"class":"du4w35lb k4urcfbm l9j0dhe7 sjgh65i0"})
#15

comments=[]
for i in all_posts:
    

    k=i.find_all("div",{"class":"ecm0bbzt e5nlhep0 a8c37x1j"})
    m=[]
    print('post-------------------------------')
    for j in k:
        print(j.text)
        m.append(j.text)
    comments.append(m)
# Out:
# post-------------------------------
# Mais non,il suffit de ne plus être au pouvoir,et si en plus on sort un bouquin.....
# post-------------------------------
# post-------------------------------
# Yeeeeeaaaaahhhhhh ! ! !
# !
# hhhh
# post-------------------------------
# post-------------------------------
# ouf la mort
# post-------------------------------
# post-------------------------------
# post-------------------------------
# post-------------------------------
# post-------------------------------
# post-------------------------------
# post-------------------------------
# post-------------------------------
# post-------------------------------
# post-------------------------------
# post-------------------------------
# post-------------------------------
# post-------------------------------
# post-------------------------------
# post-------------------------------
# post-------------------------------
# post-------------------------------
# ...

# %%
#16
comments
# Out:
# [['Mais non,il suffit de ne plus être au pouvoir,et si en plus on sort un bouquin.....'],
#  [],
#  ['Yeeeeeaaaaahhhhhh ! ! !', '!', 'hhhh'],
#  [],
#  ['ouf la mort'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  []]

# %%
pubs=[]
for i in range(len(images)):
    pubs.append({"images":images[i],"descriptions":descriptions[i],"comments":comments[i]})

# %%
pubs
# Out:
# [{'images': 'https://scontent.ftun15-1.fna.fbcdn.net/v/t1.6435-9/70218735_2520182701394690_4579251791207596032_n.jpg?stp=dst-jpg_s1080x2048&_nc_cat=110&ccb=1-5&_nc_sid=730e14&_nc_ohc=qiwu30SPiqcAX-1TXXG&_nc_ht=scontent.ftun15-1.fna&oh=00_AT9hoz9xfsS3DVeI-gNmQI6IJiQ8w-pLG8vOH_DSB5CZNQ&oe=62898F30',
#   'descriptions': 'Le #DessinDePresse de Zaïtchick : To be or not to be... Not to be !Emmanuel Macron et Christophe Castaner : « - Comment devenir aussi populaire que Jacques Chirac ?...- Heu… Mourez ?- Merci Christophe… J’y réfléchirai… »Retrouvez les dessins de Zaïtchick sur le sitehttps://www.blagues-et-dessins.com/.../l-actu-de-zaitchick/#DessinDeZaitchick #ActuDeZaitchick #Humour #HumourNoir #RIPJacquesChirac #DécèsDeJacquesChirac #JacquesChirac #MortDeJacquesChirac #DisparitionDeJacquesChirac #EmmanuelMacron #ChristopheCastaner',
#   'comments': ['Mais non,il suffit de ne plus être au pouvoir,et si en plus on sort un bouquin.....']},
# ...

# %%
#MongoDB connection

client =MongoClient("mongodb+srv://mongo:5BLcL4zoHMusclMO@cluster0.yxypy.mongodb.net/myFirstDatabase?retryWrites=true&w=majority")

mydb = client["Facebook"]
mycol = mydb["posts"]

#insert the list of dicts
mycol.insert_many(pubs)

#Show a sample 
mycol.find_one()
# Out:
# {'_id': ObjectId('62648424c9ca3b74dc0bfce9'),
#  'images': 'https://scontent.ftun15-1.fna.fbcdn.net/v/t1.6435-9/70218735_2520182701394690_4579251791207596032_n.jpg?stp=dst-jpg_s1080x2048&_nc_cat=110&ccb=1-5&_nc_sid=730e14&_nc_ohc=qiwu30SPiqcAX-1TXXG&_nc_ht=scontent.ftun15-1.fna&oh=00_AT9hoz9xfsS3DVeI-gNmQI6IJiQ8w-pLG8vOH_DSB5CZNQ&oe=62898F30',
#  'descriptions': 'Le #DessinDePresse de Zaïtchick : To be or not to be... Not to be !Emmanuel Macron et Christophe Castaner : « - Comment devenir aussi populaire que Jacques Chi… Voir plus',
#  'comments': ['Mais non,il suffit de ne plus être au pouvoir,et si en plus on sort un bouquin.....']}

# %%
#end
driver.close()
